# %% [markdown]
# Description:
#
# This Python code uses the Pandas library and then creates visualizations to analyze and understand the data.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from numpy import array
import seaborn as sb
# %matplotlib inline

# %%
df_1 = pd.read_excel('E:/aks haye maghale/PAPER1.xlsx')
df_2 = pd.read_excel('E:/aks haye maghale/PAPER2.xlsx')
df_3 = pd.read_excel('E:/aks haye maghale/PAPER3.xlsx')

# %%
df_1.head()
# Out:
#          SGR      RHOB      RESX       RESD       PEF        CGR      NPHI  \
# 0  51.176961  2.628873  0.769375   5.520820  4.716008  37.281224  0.096651
# 1  44.167592  2.660089  1.024691  11.494291  4.847739  32.199172  0.063781
# 2  38.065603  2.673047  1.249603  11.004464  4.943477  27.771975  0.051012
# 3  32.546572  2.672810  1.356193  10.036164  5.017874  23.921583  0.049087
# 4  30.047528  2.662965  1.394187  11.923706  5.059046  22.261396  0.047743
#
#    log (NMR_PERM)
# 0       -3.721246
# 1       -3.823909
# 2       -3.251812
# 3       -2.598599
# 4       -2.428291

# %%
df_2.head()
# Out:
#    SGR_NORM  RHOB_NORM  RESX_NORM  RESD_NORM  PEF_NORM  CGR_NORM  NPHI_NORM  \
# 0  0.426369   0.684603   0.005418   0.003898  0.626319  0.581007   0.187088
# 1  0.352876   0.719365   0.007319   0.008312  0.666668  0.490225   0.128213
# 2  0.288896   0.733794   0.008994   0.007950  0.695993  0.411140   0.105342
# 3  0.231029   0.733531   0.009788   0.007234  0.718780  0.342359   0.101894
# 4  0.204826   0.722566   0.010071   0.008629  0.731391  0.312703   0.099486
#
#    log (NMR_PERM)_NORM
# 0             0.144913
# 1             0.133279
# 2             0.198111
# 3             0.272135
# 4             0.291435

# %%
df_3.head()
# Out:
#          SGR      RHOB      RESX       RESD       PEF        CGR      NPHI  \
# 0  51.176961  2.628873  0.769375   5.520820  4.716008  37.281224  0.096651
# 1  44.167592  2.660089  1.024691  11.494291  4.847739  32.199172  0.063781
# 2  38.065603  2.673047  1.249603  11.004464  4.943477  27.771975  0.051012
# 3  32.546572  2.672810  1.356193  10.036164  5.017874  23.921583  0.049087
# 4  30.047528  2.662965  1.394187  11.923706  5.059046  22.261396  0.047743
#
#        DCAL      CALI      DRHO  log (NMR_PERM)
# 0  0.249557  8.749557  0.074962       -3.721246
# 1  0.266117  8.766117  0.049764       -3.823909
# 2  0.172033  8.672033  0.039200       -3.251812
# 3  0.089541  8.589541  0.033417       -2.598599
# 4  0.083354  8.583354  0.029113       -2.428291

# %%
df_1.describe()
# Out:
#                SGR         RHOB         RESX         RESD          PEF  \
# count  2654.000000  2654.000000  2654.000000  2654.000000  2654.000000
# mean     32.170101     2.511958     1.197345    27.060725     4.775131
# std       8.502929     0.098168     0.356510    31.003053     0.242283
# min      14.433237     2.158199     0.090633     0.659990     2.671211
# 25%      26.281077     2.435287     0.962198     4.881429     4.674691
# 50%      30.681268     2.519599     1.272208    18.821357     4.802874
# 75%      36.546400     2.580761     1.454493    34.376294     4.918636
# max     105.886340     2.774054     3.230126   236.488413     5.800828
#
#                CGR         NPHI  log (NMR_PERM)
# count  2654.000000  2654.000000     2654.000000
# mean     15.519107     0.118727       -0.771730
# std       4.488663     0.064807        1.427728
# min       5.632280    -0.000867       -5.000000
# 25%      13.128022     0.070510       -1.580172
# ...

# %%
df_2.describe()
# Out:
#           SGR_NORM    RHOB_NORM    RESX_NORM    RESD_NORM     PEF_NORM  \
# count  2654.000000  2654.000000  2654.000000  2654.000000  2654.000000
# mean      0.227081     0.554408     0.008605     0.019814     0.644429
# std       0.089154     0.109319     0.002655     0.022908     0.074211
# min       0.041109     0.160467     0.000362     0.000306     0.000003
# 25%       0.165334     0.469028     0.006854     0.003425     0.613664
# 50%       0.211471     0.562916     0.009163     0.013726     0.652927
# 75%       0.272967     0.631025     0.010520     0.025219     0.688384
# max       1.000000     0.846274     0.023745     0.174561     0.958597
#
#           CGR_NORM    NPHI_NORM  log (NMR_PERM)_NORM
# count  2654.000000  2654.000000          2654.000000
# mean      0.192263     0.226629             0.479162
# std       0.080182     0.116079             0.161795
# min       0.015651     0.012417             0.000000
# 25%       0.149550     0.140265             0.387547
# ...

# %%
df_3.describe()
# Out:
#                SGR         RHOB         RESX         RESD          PEF  \
# count  2654.000000  2654.000000  2654.000000  2654.000000  2654.000000
# mean     32.170101     2.511958     1.197345    27.060725     4.775131
# std       8.502929     0.098168     0.356510    31.003053     0.242283
# min      14.433237     2.158199     0.090633     0.659990     2.671211
# 25%      26.281077     2.435287     0.962198     4.881429     4.674691
# 50%      30.681268     2.519599     1.272208    18.821357     4.802874
# 75%      36.546400     2.580761     1.454493    34.376294     4.918636
# max     105.886340     2.774054     3.230126   236.488413     5.800828
#
#                CGR         NPHI         DCAL         CALI         DRHO  \
# count  2654.000000  2654.000000  2654.000000  2654.000000  2654.000000
# mean     15.519107     0.118727     0.157996     8.657996     0.009063
# std       4.488663     0.064807     0.446394     0.446394     0.034772
# ...

# %%
def show_heatmap(data):
    plt.figure(figsize = (10,10) , dpi = 300)
    plt.matshow(data.corr())
    plt.xticks(range(data.shape[1]), data.columns, fontsize=14, rotation=90)
    plt.gca().xaxis.tick_bottom()
    plt.yticks(range(data.shape[1]), data.columns, fontsize=14)

    cb = plt.colorbar()
    cb.ax.tick_params(labelsize=14)
    plt.title("Feature Correlation Heatmap", fontsize=14)
    plt.show()


show_heatmap(df_3)

# %%
import matplotlib as mpl
mpl.rcParams["axes.labelsize"] = 25
plt.figure(figsize = (10,10) , dpi = 300)
b = sb.pairplot(df_3,diag_kind = 'kde' , kind = 'reg')
plt.show()
#plt.savefig('plot.png', dpi=300, bbox_inches='tight')
